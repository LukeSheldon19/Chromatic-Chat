# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/final_dataset.csv')
df.head()
# Out:
#                                                 text     emotion
# 0  i feel rather funny ending with so many dupes ...         fun
# 1                     i feel surprised by the result    surprise
# 2                    i am officially feeling festive     neutral
# 3  i suddenly found myself standing before this w...    surprise
# 4  i look at the meager pile of food i purchased ...  enthusiasm

# %%
np.unique(df['emotion'])
# Out:
# array(['anger', 'empty', 'enthusiasm', 'fun', 'happiness', 'hate', 'love',
#        'neutral', 'relief', 'sadness', 'surprise'], dtype=object)

# %%
test_rows = df.head(20)
test_rows
# Out:
#                                                  text     emotion
# 0   i feel rather funny ending with so many dupes ...         fun
# 1                      i feel surprised by the result    surprise
# 2                     i am officially feeling festive     neutral
# 3   i suddenly found myself standing before this w...    surprise
# 4   i look at the meager pile of food i purchased ...  enthusiasm
# 5   I, for one, am thrilled that Christ works outs...   happiness
# 6   i hate that she has the power to make me feel ...        hate
# 7                             i feel like i missed it     neutral
# 8   i have personally experienced this gut wrenchi...     sadness
# 9   i hate feeling that people see me as ugly but ...        hate
# 10  Branson was nonplussed by Elliott 's refusal ;...    surprise
# 11  i dont know why but i had the impression that ...       empty
# 12  i joined as a favor to my buddy and out of my ...     neutral
# 13    i am feeling irritated and empty and lost today       empty
# 14  ive become in a mere years yeah right o but i ...  enthusiasm
# 15                     i wanna feel absolutely lovely        love
# 16  i started to feel shaky like i was about to ha...     sadness
# 17  Mala Rodriguez is on Rome Santos album? she's ...    surprise
# 18     i always feel like i am hated among my friends        hate
# 19  i was working with one of my heroes so it was ...  enthusiasm

# %%
# !pip install psycopg2-binary pgvector
# Out:
# Requirement already satisfied: psycopg2-binary in c:\users\lshel\anaconda3\lib\site-packages (2.9.11)
# Requirement already satisfied: pgvector in c:\users\lshel\anaconda3\lib\site-packages (0.3.6)
# Requirement already satisfied: numpy in c:\users\lshel\anaconda3\lib\site-packages (from pgvector) (1.24.4)

# %%
# --- Now let me gen embeddings for first 20 rows so that I can connect and dump in db ---

# %%
import re

# %%
test_rows['text'] = test_rows['text'].apply(
    lambda x: re.sub(r'[^\w\s]', '', str(x)) if isinstance(x, str) else None
)
# Out:
# C:\Users\LShel\AppData\Local\Temp\ipykernel_38384\509755466.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_rows['text'] = test_rows['text'].apply(

# %%
import torch
from transformers import AutoTokenizer, AutoModel

# %%
model_ckpt = 'sentence-transformers/all-MiniLM-L6-v2'
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
model = AutoModel.from_pretrained(model_ckpt)

# %%
sents = test_rows['text'].tolist()
labels = test_rows['emotion'].tolist()

# %%
encoded_input = tokenizer(sents, padding=True, truncation=True, return_tensors="pt")

# %%
with torch.no_grad():
    model_output = model(**encoded_input)

# %%
import torch.nn.functional as F

def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output.last_hidden_state
    input_mask_expanded = (
        attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    )
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(
        input_mask_expanded.sum(1), min=1e-9
    )

# %%
sentence_embeddings = mean_pooling(model_output, encoded_input["attention_mask"])
sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)
print(f"Sentence embeddings shape: {sentence_embeddings.size()}")
# Out:
# Sentence embeddings shape: torch.Size([20, 384])

# %%
# --- setting up db connection with langchain PGVector Object ---

# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\users\lshel\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in c:\users\lshel\anaconda3\lib\site-packages (from langchain) (1.2.5)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\lshel\anaconda3\lib\site-packages (from langchain) (1.0.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\lshel\anaconda3\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.5.1)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (8.2.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.12.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\lshel\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\lshel\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\lshel\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.1)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\lshel\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lshel\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\lshel\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\lshel\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\lshel\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain) (2.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\lshel\anaconda3\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\lshel\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\lshel\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\lshel\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\lshel\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.31.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\lshel\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\lshel\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (4.2.0)
# Requirement already satisfied: certifi in c:\users\lshel\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\lshel\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\lshel\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.4)
# Requirement already satisfied: h11>=0.16 in c:\users\lshel\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lshel\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lshel\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.0.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\lshel\anaconda3\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.3.0)

# %%
# !pip install -qU langchain-postgres

# %%
# !pip install --upgrade langchain langchain-core langchain-postgres typing_extensions
# Out:
# Requirement already satisfied: langchain in c:\users\lshel\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: langchain-core in c:\users\lshel\anaconda3\lib\site-packages (1.2.5)
# Requirement already satisfied: langchain-postgres in c:\users\lshel\anaconda3\lib\site-packages (0.0.16)
# Requirement already satisfied: typing_extensions in c:\users\lshel\anaconda3\lib\site-packages (4.15.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\lshel\anaconda3\lib\site-packages (from langchain) (1.0.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\lshel\anaconda3\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-core) (0.5.1)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-core) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-core) (8.2.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-core) (0.12.0)
# Requirement already satisfied: asyncpg>=0.30.0 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-postgres) (0.31.0)
# Requirement already satisfied: numpy<3,>=1.21 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-postgres) (1.24.4)
# Requirement already satisfied: pgvector<0.4,>=0.2.5 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-postgres) (0.3.6)
# Requirement already satisfied: psycopg-pool<4,>=3.2.1 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-postgres) (3.3.0)
# Requirement already satisfied: psycopg<4,>=3 in c:\users\lshel\anaconda3\lib\site-packages (from psycopg[binary]<4,>=3->langchain-postgres) (3.3.2)
# Requirement already satisfied: sqlalchemy<3,>=2 in c:\users\lshel\anaconda3\lib\site-packages (from sqlalchemy[asyncio]<3,>=2->langchain-postgres) (2.0.25)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\lshel\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (2.1)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\lshel\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\lshel\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\lshel\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.1)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\lshel\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\lshel\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\lshel\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\lshel\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\lshel\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.31.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\lshel\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: tzdata in c:\users\lshel\anaconda3\lib\site-packages (from psycopg<4,>=3->psycopg[binary]<4,>=3->langchain-postgres) (2023.3)
# Requirement already satisfied: psycopg-binary==3.3.2 in c:\users\lshel\anaconda3\lib\site-packages (from psycopg[binary]<4,>=3->langchain-postgres) (3.3.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lshel\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\lshel\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\lshel\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\lshel\anaconda3\lib\site-packages (from sqlalchemy<3,>=2->sqlalchemy[asyncio]<3,>=2->langchain-postgres) (3.0.1)
# Requirement already satisfied: anyio in c:\users\lshel\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.2.0)
# Requirement already satisfied: certifi in c:\users\lshel\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\lshel\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: idna in c:\users\lshel\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4)
# Requirement already satisfied: h11>=0.16 in c:\users\lshel\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\lshel\anaconda3\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lshel\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lshel\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.0.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\lshel\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.0)

# %%
pip install --upgrade typing_extensions
# Out:
# Requirement already satisfied: typing_extensions in c:\users\lshel\anaconda3\lib\site-packages (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain-huggingface
# Out:
# Requirement already satisfied: langchain-huggingface in c:\users\lshel\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.33.4 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-huggingface) (0.36.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.0 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-huggingface) (1.2.5)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-huggingface) (0.19.1)
# Requirement already satisfied: filelock in c:\users\lshel\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lshel\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\lshel\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lshel\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (6.0.1)
# Requirement already satisfied: requests in c:\users\lshel\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\lshel\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lshel\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.5.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (2.12.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (8.2.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\lshel\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\lshel\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\lshel\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\lshel\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\lshel\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\lshel\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lshel\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\lshel\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\lshel\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lshel\anaconda3\lib\site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lshel\anaconda3\lib\site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lshel\anaconda3\lib\site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lshel\anaconda3\lib\site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2024.12.14)
# Requirement already satisfied: colorama in c:\users\lshel\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (0.4.6)
# Requirement already satisfied: anyio in c:\users\lshel\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\lshel\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\lshel\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\lshel\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\lshel\anaconda3\lib\site-packages (5.2.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\lshel\anaconda3\lib\site-packages (from sentence-transformers) (4.42.4)
# Requirement already satisfied: tqdm in c:\users\lshel\anaconda3\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\lshel\anaconda3\lib\site-packages (from sentence-transformers) (2.3.1+cu118)
# Requirement already satisfied: scikit-learn in c:\users\lshel\anaconda3\lib\site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in c:\users\lshel\anaconda3\lib\site-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\lshel\anaconda3\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\lshel\anaconda3\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in c:\users\lshel\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lshel\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\lshel\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lshel\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in c:\users\lshel\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: sympy in c:\users\lshel\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in c:\users\lshel\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in c:\users\lshel\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\lshel\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\lshel\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: numpy<2.0,>=1.17 in c:\users\lshel\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (1.24.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lshel\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2023.10.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\lshel\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\lshel\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\lshel\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lshel\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\lshel\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.11.0->sentence-transformers) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\lshel\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.11.0->sentence-transformers) (2021.13.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lshel\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lshel\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lshel\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lshel\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lshel\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.12.14)
# Requirement already satisfied: mpmath>=0.19 in c:\users\lshel\anaconda3\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_postgres import PGVector

# %%
CONNECTION_STRING = "postgresql+psycopg2://postgres:test@localhost:5432/vector_db"
COLLECTION_NAME = "test_vectors"

# %%
final_embeddings = sentence_embeddings.numpy().tolist()

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# %%
vector_store = PGVector(
    embeddings=embedding_model,
    collection_name=COLLECTION_NAME,
    connection=CONNECTION_STRING,
    use_jsonb=True,
)

# %%
from langchain_core.documents import Document

# %%
docs = []

for i in range(len(sents)):
    doc = Document(
        page_content=sents[i],
        metadata={"label": labels[i]},
    )
    docs.append(doc)

# %%
vector_store.add_documents(docs)
# Out:
# ['27fd290d-23c7-44aa-805f-583ddde2bf2c',
#  'b8fbcce3-7641-43a4-8529-85e5aa64fa4a',
#  '9c30bb36-fbf7-483e-a9b5-126e8c7a30b1',
#  '49e55d51-f26c-4877-94dd-021b990d7856',
#  'f71d1cb1-8f73-4ced-9fd8-2e5a0897e5fd',
#  '07fb5a1d-a6db-4608-a3ca-b6a7fef5058f',
#  'b7a52719-29f5-43cb-81d4-65a91c8b808a',
#  '7783ddd0-4dbc-49b0-bb08-020997fb9f37',
#  'bf25e9cc-208e-42c2-acf4-b76d7ec93661',
#  '13db85ce-6d63-4a7d-844c-8e2784043143',
#  'ebe016f9-4a27-4774-8ff4-b3ee9200c08b',
#  'a6206d16-5b34-4fc4-83bd-c55bff96c7db',
#  '0a371fff-0991-4729-9a31-0178ca60dfab',
#  '6c5b0d47-80a5-4ddd-b6b7-1b82e8f60717',
#  '942d239b-019c-4b50-b7aa-99767cfee104',
#  '1d01fe77-dc63-4ef0-829e-88bc9b9a8843',
#  '61042370-1479-4cdb-878a-cc7ee1c0a8a6',
#  'f3613b9c-cfdf-4c7b-8374-15bc6647669b',
#  '85c43b88-d930-407f-b05e-8b51ca336fff',
#  '4af82102-ad91-4531-934b-f78cd6d37ecf']

# %%
results = vector_store.similarity_search(
    "Wow I did not think that was going to happen", k=5
)
for doc in results:
    print(f"* {doc.page_content} [{doc.metadata}]")
# Out:
# * i feel surprised by the result [{'label': 'surprise'}]
# * i feel like i missed it [{'label': 'neutral'}]
# * I for one am thrilled that Christ works outside of our timeline He is so faithful And sovereign [{'label': 'happiness'}]
# * i suddenly found myself standing before this woman dressed like a priestess with white robes and egyptian jewellery long black hair and realized that i was feeling amorous and passionate and noticed to my surprise that my breath was green i was breathing out clouds of green energy [{'label': 'surprise'}]
# * i was working with one of my heroes so it was a combination of feeling intimidated excited and thrilled [{'label': 'enthusiasm'}]

# %%
results2 = vector_store.similarity_search_with_score(
    "I really hate going to the beach so much", k=5
)
for doc, score in results2:
    print(f"* [SIM={score:3f}] {doc.page_content} [{doc.metadata}]")
# Out:
# * [SIM=0.684024] i always feel like i am hated among my friends [{'label': 'hate'}]
# * [SIM=0.697759] i hate that she has the power to make me feel such ugly things [{'label': 'hate'}]
# * [SIM=0.752931] i wanna feel absolutely lovely [{'label': 'love'}]
# * [SIM=0.775491] i look at the meager pile of food i purchased for the week i am feeling pretty apprehensive [{'label': 'enthusiasm'}]
# * [SIM=0.812117] ive become in a mere years yeah right o but i really just feel so eager for it all [{'label': 'enthusiasm'}]
